# %%
import pandas as pd
import numpy as np
from sklearn import cross_validation

data_csv = pd.read_csv('menkyo_info.csv',header=None)
data_csv.columns = ['moji','label']
moji = data_csv['moji']
#moji_array = np.array(moji)
moji_list = moji.tolist()

label = data_csv['label']
#label_array = np.array(label)
#print(label_array)
lbl_list = label.tolist()
label_li = []
for lbl in lbl_list:
    for i in range(5):
        label_li.append(lbl)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences


moji_str =  ''
for mojis in moji_list:
    moji_str += mojis

tokenizer = Tokenizer()
tokenizer.fit_on_texts(moji_str)
moji_seq = tokenizer.texts_to_sequences(moji_str)
vocab_size = len(tokenizer.word_index) + 1
# Out:
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %%
    
    
import numpy as np 


point = np.load('zahyou.npy')
#print(point)
xmin = []
ymin = []
xmax = []
ymax = []
for p in point:
    xmin.append(p[0])
    ymin.append(p[1])
    xmax.append(p[2])
    ymax.append(p[3])
    
#print(len(xmin_zahyou))

# 文字と座標は独立していて良い！！それぞれ一つ一つにラベルが振ってあれば問題なし
#data=[文字列、座標]
data = []
#moji_zahyou = []
for idx in range(len(xmin)):
    
    data.append(moji_seq[idx])
    
    data.append([xmin[idx]])

    data.append([ymin[idx]])
    
    data.append([xmax[idx]])
    
    data.append([ymax[idx]])
    
    #data.append(moji_zahyou)
#print('data',len(data))
#print('xmins',len(xmins))
#print(data)


count_max = []
#moji_zahyou = []
for idx in range(len(xmin)):
    
    count_max.append(moji_seq[idx][0])
    
    count_max.append(xmin[idx])

    count_max.append(ymin[idx])
    
    count_max.append(xmax[idx])
    
    count_max.append(ymax[idx])
    
max_num = max(count_max)

print(data)
# Out:
# [[17], [19], [50], [33], [72], [18], [36], [48], [51], [71], [19], [71], [45], [96], [75], [20], [125], [48], [150], [78], [21], [200], [46], [224], [76], [22], [250], [46], [279], [75], [6], [421], [46], [438], [71], [7], [439], [44], [453], [76], [8], [469], [42], [483], [73], [4], [487], [46], [502], [75], [2], [507], [47], [523], [74], [1], [519], [45], [533], [72], [9], [538], [48], [557], [71], [10], [568], [44], [586], [71], [13], [595], [48], [610], [71], [23], [615], [46], [626], [72], [24], [18], [110], [35], [132], [25], [37], [112], [53], [138], [26], [73], [112], [96], [135], [27], [95], [110], [125], [137], [28], [128], [112], [151], [135], [29], [153], [110], [176], [140], [30], [173], [108], [204], [139], [31], [205], [110], [229], [138], [32], [232], [109], [254], [139], [33], [254], [110], [276], [138], [34], [279], [110], [305], [138], [14], [309], [114], [326], [136], [14], [333], [111], [358], [138], [15], [355], [108], [385], [138], [35], [382], [109], [405], [139], [36], [407], [112], [431], [135], [11], [433], [110], [460], [142], [37], [18], [143], [35], [166], [38], [36], [144], [54], [167], [6], [85], [143], [109], [165], [7], [109], [142], [128], [168], [1], [126], [142], [144], [166], [5], [144], [137], [159], [166], [4], [159], [143], [180], [168], [2], [186], [142], [204], [167], [1], [201], [140], [217], [167], [9], [216], [140], [235], [168], [1], [237], [142], [257], [165], [12], [253], [139], [274], [166], [13], [274], [143], [290], [166], [5], [314], [144], [329], [164], [5], [328], [137], [344], [166], [8], [343], [142], [360], [166], [12], [360], [142], [375], [167], [39], [380], [140], [393], [165], [6], [21], [173], [48], [210], [7], [45], [172], [81], [214], [16], [79], [172], [103], [208], [3], [105], [172], [130], [208], [4], [128], [169], [155], [208], [3], [157], [171], [182], [209], [2], [183], [168], [207], [208], [9], [207], [171], [230], [208], [3], [232], [172], [252], [205], [10], [253], [172], [276], [204], [4], [272], [171], [301], [205], [40], [298], [171], [317], [204], [41], [318], [173], [347], [204], [42], [347], [172], [374], [207], [43], [374], [172], [403], [208], [44], [21], [215], [31], [237], [45], [30], [218], [44], [236], [46], [45], [215], [59], [237], [47], [18], [237], [32], [259], [48], [30], [237], [46], [264], [49], [44], [235], [59], [255], [15], [16], [316], [30], [339], [11], [33], [316], [46], [336], [50], [58], [314], [83], [342], [2], [109], [310], [131], [342], [1], [126], [311], [150], [342], [51], [142], [311], [168], [338], [12], [169], [310], [186], [339], [3], [185], [310], [205], [338], [1], [205], [310], [224], [337], [16], [222], [311], [244], [335], [2], [245], [311], [261], [337], [3], [258], [310], [280], [335], [10], [279], [308], [298], [337], [5], [297], [304], [316], [335], [8], [317], [311], [336], [335], [11], [354], [310], [380], [335]]

# %%
from keras.layers import Dense,LSTM, Activation
from keras.models import Sequential
from keras.utils import np_utils
from keras.layers.embeddings import Embedding
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.optimizers import Adadelta,Adam


#moji_train = np.array(moji_train)
#moji_test = np.array(moji_test)
#label_train = np.array(label_train)
#label_test = np.array(label_test)


labels = list(set(label_li))
label_dic = {}
for idx, lbl in enumerate(labels):
     label_dic[idx] = lbl

print(label_dic)

nb_label = len(labels)
#print(nb_label)
#print(label_train)

label_list =[]
for label in label_li:
    for key , val in label_dic.items():
        if val == label:
            label_list.append(key)
        else:continue
        
    
moji_train, moji_test, label_train, label_test = cross_validation.train_test_split(data, label_list)


moji_train = np.array(moji_train)
moji_test = np.array(moji_test)
label_train2 = np.array(label_train)
label_test2 = np.array(label_test)

print('label_train',label_train)

for train in moji_train:
    num = len(train)


#reshape(データセットの数＝LSTMのタイムステップ、一度に入力させたいデータの数＝データを何個使って予測をさせるか、データ１種類につき１個のデータだから１)
#moji_tra = moji_train.reshape( len(moji_train) , 1, 1)
moji_tra = moji_train.reshape( len(moji_train) , num)
#moji_tes = moji_test.reshape( len(moji_test) , 1, 1)
moji_tes = moji_test.reshape( len(moji_test) , num)
#label_tra = label_train.reshape( len(label_train) , 1, 1)
#label_tes = label_test.reshape( len(label_test) , 1, 1)
label_train = np_utils.to_categorical(label_train2, nb_label)
label_test = np_utils.to_categorical(label_test2, nb_label)




batch_size = 2

# 出力する時の次元数。CNNと違って中間層は入力データによって変わるから。
# 何種類のデータを一度に出力するか
neurons = 70
neurons2 = 70
neurons3 = 100


#This is the size of the vocabulary in the text data. 
#For example, if your data is integer encoded to values between 0-10, then the size of the vocabulary would be 11 words.
#  入力の形や出力の形には影響しない
# 単語をtexts_to_sequences() で整数にするんだが、その整数の最大値+1を入力する
#  tokenizer = Tokenizer()
#vocab_size = len(tokenizer.word_index) + 1 これで単語を整数にした時の最大の整数＋１がわかる。
# 単語をベクトルにした時の最大の数字をかく

#[[16 12 18 17 16]
# [ 8 14  6 15 19]]なら１９＋１で２０
#num_word = vocab_size 
num_word = max_num +1

# ここから二つが出力の形に関わる。出力はinput_length が行数になり、embedding_vecor_lengthが列数次元数になる


# 出力した時の一単語につき〜次元で出力　埋め込みベクトルのサイズを示す。単語の数でいいと思われ
#[[16 12 18 17 16]
# [ 8 14  6 15 19]]  なら、ここを１０に設定すると、この5列が10列に引き延ばされる。ただの数字の整数を何次元まで伸ばすか＝何列まで引き延ばすか
#１０にすると、「16」→[ 0.028 0.021 0.005 -0.024 0.024 -0.037 -0.039 -0.013 -0.035 0. ]
# 特に決まりはなさげ。前に学習した単語が１００次元ならここも１００にしたりとか４次元のベクトルに変換した後に８次元にしたりとか
embedding_vecor_length = 2

#input_length argumetは各入力シーケンスのサイズを決定します。入力するリストの中のリストのデータの個数
#  それぞれ入力する時の文字数、リストの中のリストの中の要素の数！！！
#[[16 12 18 17 16]
# [ 8 14  6 15 19]]  ならinput_length = 5
# この数が出力時の配列の行数になる！！一つ一つの単語をembedding_vecor_length次元まで伸ばして、一要素ずつ（リストの中のリストの中の要素数）縦に置いていくイメージ。
# 一要素ずつ縦に置いていく時にここで指定した数の分だけ、縦に配置される
#[[2 3 1 2 1]
# [3 3 0 2 3]]が入力で　input_length =５なら
#[[[ 0.03530972 -0.01738765]
#  [-0.01431809  0.02838255]
#  [-0.00195207  0.04445304]
#  [ 0.03530972 -0.01738765]
#  [-0.00195207  0.04445304]]
#
# [[-0.01431809  0.02838255]
#  [-0.01431809  0.02838255]
#  [-0.00543046 -0.01861401]
#  [ 0.03530972 -0.01738765]
#  [-0.01431809  0.02838255]]]
#　それぞれのリストの中のリストの中の数字が縦に置かれて、それが横へ１次元から２次元へ引き伸ばされている
#  入力の列の数が出力の行数になる！！
input_length = 1

def build_model(train_data , neurons ,neurons2,neurons3, batich_size):
    model = Sequential()
    #model.add(Embedding(num_words, embedding_vecor_length, input_length=max_speech_length))
    model.add(Embedding(num_word,embedding_vecor_length,input_length = input_length))
    model.add(Conv1D(32, 3, border_mode='same', activation='relu'))
    #model.add(LSTM(neurons, batch_input_shape= (batch_size, train_data.shape[1], train_data.shape[2]) ))
    #  ,stateful=True
    model.add(LSTM(neurons, batch_input_shape= (batch_size, train_data.shape[1]), activation='relu',return_sequences = True ))
    model.add(LSTM(neurons2,return_sequences = True ))
    model.add(LSTM(neurons3,return_sequences = False ))
    #model.add(Dense(100, activation='relu'))
    model.add(Dense(7, activation='softmax'))
    #Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0)
    Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model


#  fitは学習データは3次元のarrayで渡す,ラベルは１次元のarrayで渡す！！
#  作ったモデルを関数にして、modelインスタンスに格納してfitで使わないと動かない 

model = build_model(moji_tra , neurons , neurons2 , neurons3 ,1)
# Out:
# {0: '住所', 1: 'ラベル', 2: '生年月日', 3: '番号', 4: '交付', 5: '氏名', 6: '有効年月日'}
# label_train [1, 6, 1, 6, 4, 3, 1, 1, 6, 3, 4, 4, 3, 1, 1, 4, 0, 6, 1, 1, 6, 4, 2, 1, 2, 4, 6, 0, 2, 4, 5, 3, 3, 6, 3, 3, 3, 1, 0, 2, 2, 0, 3, 4, 3, 0, 5, 0, 2, 1, 0, 6, 4, 2, 3, 1, 0, 4, 3, 4, 4, 3, 6, 1, 1, 5, 6, 6, 6, 6, 2, 0, 4, 6, 4, 0, 1, 2, 1, 1, 1, 1, 0, 4, 1, 6, 4, 2, 1, 0, 2, 6, 2, 3, 6, 1, 4, 1, 6, 6, 1, 0, 4, 6, 1, 4, 4, 4, 2, 4, 4, 6, 0, 0, 2, 1, 6, 4, 1, 0, 0, 3, 0, 2, 1, 6, 0, 4, 3, 4, 3, 6, 1, 6, 1, 3, 1, 4, 0, 5, 6, 6, 2, 3, 4, 3, 5, 0, 4, 1, 0, 0, 1, 6, 6, 5, 6, 2, 4, 4, 6, 4, 4, 5, 2, 4, 3, 2, 3, 0, 1, 4, 1, 0, 3, 6, 6, 4, 0, 4, 4, 3, 3, 4, 0, 3, 4, 3, 1, 4, 4, 2, 2, 1, 2, 3, 0, 1, 0, 1, 0, 1, 0, 6, 6, 6, 4, 3, 5, 4, 6, 3, 4, 6, 3, 1, 0, 3, 2, 2, 5, 0, 1, 3, 4, 1, 0, 1, 0, 2, 2, 3, 6, 3, 6, 0, 1, 0, 0, 1, 6, 0, 4, 1, 6, 2, 0, 5, 2, 1, 1, 1, 3, 0, 6, 3, 2, 6, 1, 6, 4, 6, 4, 4, 6, 0, 6, 6, 1, 5, 4, 2, 6, 2, 2, 5, 6, 1, 3, 2, 0, 0, 6, 6, 3, 1, 1, 6, 1, 0, 3, 2, 2, 4, 0, 3, 0, 4, 6, 0, 1, 3, 0, 0, 3, 4, 3, 0, 0, 5, 1, 4, 3, 6, 1, 3, 4, 4, 6, 4, 4, 3, 4, 2, 4, 3, 0, 1, 2, 1]
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:120: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(32, 3, activation="relu", padding="same")`
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1190: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1297: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
model.fit(moji_tra, label_train, epochs=30 ,batch_size=batch_size,validation_data=(moji_tes, label_test))
model.reset_states()
# Out:
# Train on 330 samples, validate on 110 samples
# Epoch 1/30
# 330/330 [==============================] - 6s - loss: 1.9262 - acc: 0.1515 - val_loss: 1.9162 - val_acc: 0.1727
# Epoch 2/30
# 330/330 [==============================] - 2s - loss: 1.8856 - acc: 0.1818 - val_loss: 1.9123 - val_acc: 0.1273
# Epoch 3/30
# 330/330 [==============================] - 2s - loss: 1.8723 - acc: 0.1697 - val_loss: 1.8982 - val_acc: 0.1273
# Epoch 4/30
# 330/330 [==============================] - 2s - loss: 1.7827 - acc: 0.2212 - val_loss: 1.8724 - val_acc: 0.1727
# Epoch 5/30
# 330/330 [==============================] - 3s - loss: 1.6792 - acc: 0.2636 - val_loss: 1.9263 - val_acc: 0.2000
#   1.67427644e-01 1.24303401e-02 5.48173130e-01]
#  [5.26719242e-02 1.09867649e-02 2.07510471e-01 2.05131188e-01
#   2.54133016e-01 4.42245491e-02 2.25342080e-01]
#  [3.74613404e-02 5.64847402e-02 1.34510572e-06 2.38803010e-02
#   8.75134408e-01 8.13721897e-07 7.03697372e-03]
#  [4.76906821e-02 1.65771116e-02 2.94893414e-01 1.88121855e-01
#   2.40488872e-01 6.38194084e-02 1.48408666e-01]
#  [1.31687545e-03 2.93124884e-01 9.58765298e-02 4.99835551e-01
#   1.69160799e-03 1.07790582e-01 3.63950850e-04]]

# %%
# 座標も含めてどれに該当するか
answer1 = []
for pre in predict:
    for idx , num in enumerate(pre):
        if num == np.max(pre):
            ans = label_dic[idx]
            answer1.append(ans)

label = []
for lbl_test in label_test2:
    lbl = label_dic[lbl_test]
    label.append(lbl)
            
print('\n正解',' 　　　　', '予想', sep='\t')   



for idx in range(len(label_test)):
    
    print(label[idx],'　　',answer1[idx],sep='\t')
# Out:
# 正解	 　　　　	予想
# 氏名	　　	交付
# 有効年月日	　　	生年月日
# 住所	　　	番号
# 有効年月日	　　	有効年月日
# 交付	　　	交付
# 生年月日	　　	生年月日
# 交付	　　	交付
# 有効年月日	　　	番号
# 交付	　　	交付
# 番号	　　	番号
# 交付	　　	住所
# 氏名	　　	生年月日
# 氏名	　　	ラベル
# ラベル	　　	ラベル
# ラベル	　　	住所
# ラベル	　　	交付
# 氏名	　　	生年月日
# 住所	　　	住所
# 番号	　　	ラベル
# 番号	　　	有効年月日
# 交付	　　	有効年月日
# ラベル	　　	交付
# 住所	　　	有効年月日
# 生年月日	　　	生年月日
# 生年月日	　　	有効年月日
# ラベル	　　	交付
# 住所	　　	有効年月日
# 有効年月日	　　	交付
# 番号	　　	有効年月日
# 有効年月日	　　	有効年月日
# 交付	　　	有効年月日
# 番号	　　	交付
# 有効年月日	　　	有効年月日
# 住所	　　	有効年月日
# 氏名	　　	番号
# 交付	　　	交付
# 交付	　　	有効年月日
# 住所	　　	有効年月日
# ラベル	　　	生年月日
# 交付	　　	交付
# 番号	　　	交付
# 番号	　　	ラベル
# 有効年月日	　　	生年月日
# ラベル	　　	ラベル
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# 番号	　　	交付
# 有効年月日	　　	ラベル
# 交付	　　	交付
# 生年月日	　　	生年月日
# 交付	　　	有効年月日
# ラベル	　　	ラベル
# 交付	　　	有効年月日
# 番号	　　	交付
# 生年月日	　　	有効年月日
# ラベル	　　	番号
# 生年月日	　　	生年月日
# 有効年月日	　　	住所
# 住所	　　	住所
# 生年月日	　　	生年月日
# 交付	　　	交付
# 生年月日	　　	生年月日
# 交付	　　	生年月日
# ラベル	　　	番号
# 住所	　　	番号
# 番号	　　	交付
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# 生年月日	　　	有効年月日
# ラベル	　　	生年月日
# 交付	　　	交付
# 番号	　　	番号
# 住所	　　	有効年月日
# 有効年月日	　　	有効年月日
# 住所	　　	住所
# 番号	　　	番号
# ラベル	　　	生年月日
# 生年月日	　　	有効年月日
# 交付	　　	交付
# 番号	　　	生年月日
# 住所	　　	住所
# 住所	　　	有効年月日
# 交付	　　	交付
# 住所	　　	有効年月日
# 生年月日	　　	ラベル
# 生年月日	　　	交付
# 番号	　　	ラベル
# 有効年月日	　　	有効年月日
# 氏名	　　	生年月日
# 有効年月日	　　	生年月日
# 番号	　　	有効年月日
# 住所	　　	有効年月日
# 交付	　　	交付
# 住所	　　	有効年月日
# 生年月日	　　	生年月日
# 氏名	　　	有効年月日
# 住所	　　	住所
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# ラベル	　　	ラベル
# 住所	　　	生年月日
# 交付	　　	有効年月日
# 住所	　　	住所
# 番号	　　	有効年月日
# 住所	　　	有効年月日
# ラベル	　　	住所
# 住所	　　	住所
# 住所	　　	生年月日
# 住所	　　	住所
# 番号	　　	有効年月日

# %%
#  免許証で出力した順に
answer = []
for pre in predicted:
    for idx , num in enumerate(pre):
        if num == np.max(pre):
            ans = label_dic[idx]
            answer.append(ans)

label = []
for lbl_test in label_list:
    lbl = label_dic[lbl_test]
    label.append(lbl)
            
print('\n正解',' 　　　　', '予想', sep='\t')   



for idx in range(len(lbl_list)):
    
    print(lbl_list[idx],'　　',answer[idx],sep='\t')
# Out:
# 正解	 　　　　	予想
# ラベル	　　	ラベル
# ラベル	　　	ラベル
# 氏名	　　	ラベル
# 氏名	　　	有効年月日
# 氏名	　　	交付
# 氏名	　　	生年月日
# 生年月日	　　	交付
# 生年月日	　　	交付
# 生年月日	　　	生年月日
# 生年月日	　　	有効年月日
# 生年月日	　　	有効年月日
# 生年月日	　　	交付
# 生年月日	　　	交付
# 生年月日	　　	交付
# 生年月日	　　	生年月日
# 生年月日	　　	生年月日
# ラベル	　　	生年月日
# ラベル	　　	ラベル
# 住所	　　	住所
# 住所	　　	生年月日
# 住所	　　	住所
# 住所	　　	住所
# 住所	　　	ラベル
# 住所	　　	住所
# 住所	　　	ラベル
# 住所	　　	ラベル
# 住所	　　	住所
# 住所	　　	住所
# 住所	　　	住所
# 住所	　　	ラベル
# 住所	　　	ラベル
# 住所	　　	ラベル
# 住所	　　	番号
# ラベル	　　	ラベル
# ラベル	　　	ラベル
# 交付	　　	交付
# 交付	　　	交付
# 交付	　　	交付
# 交付	　　	交付
# 交付	　　	有効年月日
# 交付	　　	有効年月日
# 交付	　　	交付
# 交付	　　	交付
# 交付	　　	交付
# 交付	　　	交付
# 交付	　　	生年月日
# 交付	　　	交付
# 交付	　　	交付
# 交付	　　	生年月日
# 交付	　　	交付
# 交付	　　	交付
# 有効年月日	　　	交付
# 有効年月日	　　	交付
# 有効年月日	　　	番号
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# 有効年月日	　　	交付
# 有効年月日	　　	有効年月日
# 有効年月日	　　	交付
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# 有効年月日	　　	有効年月日
# ラベル	　　	生年月日
# ラベル	　　	ラベル
# ラベル	　　	生年月日
# ラベル	　　	ラベル
# ラベル	　　	生年月日
# ラベル	　　	ラベル
# ラベル	　　	ラベル
# ラベル	　　	番号
# ラベル	　　	ラベル
# 番号	　　	有効年月日
# 番号	　　	交付
# 番号	　　	番号
# 番号	　　	交付
# 番号	　　	有効年月日
# 番号	　　	交付
# 番号	　　	番号
# 番号	　　	有効年月日
# 番号	　　	有効年月日
# 番号	　　	交付
# 番号	　　	交付
# 番号	　　	生年月日
# 番号	　　	番号
